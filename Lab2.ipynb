# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Customer-Churn-Records 2.csv")

# Display dataset shape
df.shape

# %%
# Preview first rows
df.head()

# %%
# Dataset information
df.info()
